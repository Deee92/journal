# %%
import pandas as pd

# %% [markdown]
# ## PDFBox

# %%
report = pd.read_csv("/home/dee/dev/pankti/pankti-extract/nested-method-analysis-pdfbox.csv")

# %%
report.shape
# Out:
# (15400, 9)

# %%
report.head(10)
# Out:
#                                          method-path  m-loc  \
# 0  org.apache.pdfbox.pdmodel.graphics.state.PDExt...      4
# 1  org.apache.pdfbox.pdmodel.interactive.action.P...      1
# 2  org.apache.pdfbox.pdmodel.interactive.action.P...      1
# 3  org.apache.xmpbox.schema.XMPMediaManagementSch...      1
# 4  org.apache.pdfbox.pdmodel.fdf.FDFAnnotation.ge...      2
# 5  org.apache.pdfbox.pdmodel.interactive.annotati...      3
# 6  org.apache.pdfbox.pdmodel.interactive.annotati...      3
# 7  org.apache.pdfbox.pdmodel.interactive.annotati...      2
# 8  org.apache.pdfbox.pdmodel.interactive.annotati...      2
# 9  org.apache.pdfbox.pdmodel.interactive.annotati...      2
#
#                                           invocation field/param  \
# 0             dict.getDictionaryObject(COSName.FONT)          C1
# 1        this.getCOSObject().setString("Base", base)         !C1
# 2                                this.getCOSObject()         !C1
# 3                                    addProperty(tt)         !C1
# 4  ((COSDictionary) (annot.getDictionaryObject(CO...          C1
# 5           getCOSObject().getDictionaryObject("PA")         !C1
# 6                                     getCOSObject()         !C1
# 7  ((COSDictionary) (getCOSObject().getDictionary...         !C1
# 8                                     getCOSObject()         !C1
# 9  ((COSDictionary) (getCOSObject().getDictionary...         !C1
#
#   primitive-return  n-loc non-static  mockable category
# 0              !C2      4         C4     False   DOMAIN
# 1               C2      1         C4     False   DOMAIN
# 2              !C2      1         C4     False   DOMAIN
# 3               C2      2         C4     False   DOMAIN
# 4              !C2      4         C4     False   DOMAIN
# 5              !C2      1         C4     False   DOMAIN
# 6              !C2      1         C4     False   DOMAIN
# 7              !C2      4         C4     False   DOMAIN
# 8              !C2      1         C4     False   DOMAIN
# 9              !C2      4         C4     False   DOMAIN

# %% [markdown]
# ### Nested method categories

# %%
report['category'].value_counts()
# Out:
# DOMAIN         11127
# STD_LIB         3863
# THIRD_PARTY      410
# Name: category, dtype: int64

# %% [markdown]
# ### Number of mockable methods

# %%
report['mockable'].value_counts()
# Out:
# False    14591
# True       809
# Name: mockable, dtype: int64

# %% [markdown]
# ### Mockable methods

# %%
mockables = report[report['mockable'] == True]

# %%
mockables
# Out:
#                                              method-path  m-loc  \
# 58     org.apache.pdfbox.debugger.ui.textsearcher.Sea...      6
# 59     org.apache.pdfbox.debugger.ui.textsearcher.Sea...      6
# 60     org.apache.pdfbox.debugger.ui.textsearcher.Sea...      6
# 61     org.apache.pdfbox.debugger.ui.textsearcher.Sea...      6
# 62     org.apache.pdfbox.debugger.ui.textsearcher.Sea...      6
# ...                                                  ...    ...
# 15284  org.apache.pdfbox.examples.util.PDFHighlighter...      8
# 15304  org.apache.pdfbox.pdmodel.graphics.image.PDInl...      5
# 15315  org.apache.pdfbox.pdmodel.common.PDStream.crea...      5
# 15377  org.apache.pdfbox.rendering.GroupGraphics.clip...      2
# 15378  org.apache.pdfbox.rendering.GroupGraphics.clip...      2
#
#                                               invocation field/param  \
# 58                            searchField.requestFocus()          C1
# 59                                 searchField.getText()          C1
# 60                        searchField.setText(searchKey)          C1
# 61                      searchField.setSelectionStart(0)          C1
# 62     searchField.setSelectionEnd(searchField.getTex...          C1
# ...                                                  ...         ...
# 15284                          highlighterOutput.flush()          C1
# 15304               stopFilters.contains(filters.get(i))          C1
# 15315         stopFilters.contains(nextFilter.getName())          C1
# 15377             groupG2D.clipRect(x, y, width, height)          C1
# 15378             alphaG2D.clipRect(x, y, width, height)          C1
#
#       primitive-return  n-loc non-static  mockable category
# 58                  C2      0         C4      True  STD_LIB
# 59                  C2      0         C4      True  STD_LIB
# 60                  C2      0         C4      True  STD_LIB
# 61                  C2      0         C4      True  STD_LIB
# 62                  C2      0         C4      True  STD_LIB
# ...                ...    ...        ...       ...      ...
# 15284               C2      0         C4      True  STD_LIB
# 15304               C2      0         C4      True  STD_LIB
# 15315               C2      0         C4      True  STD_LIB
# 15377               C2      0         C4      True  STD_LIB
# 15378               C2      0         C4      True  STD_LIB
#
# [809 rows x 9 columns]

# %% [markdown]
# ### Mockable method categories

# %%
mockables['category'].value_counts()
# Out:
# STD_LIB        589
# DOMAIN         195
# THIRD_PARTY     25
# Name: category, dtype: int64

# %% [markdown]
# ## BroadLeaf

# %%
report = pd.read_csv("/home/dee/dev/pankti/pankti-extract/nested-method-analysis-broadleaf.csv")

# %%
report.shape
# Out:
# (36858, 9)

# %%
report.head(10)
# Out:
#                                          method-path  m-loc  \
# 0  org.broadleafcommerce.openadmin.server.dao.Met...      4
# 1  org.broadleafcommerce.openadmin.server.dao.Met...      4
# 2  org.broadleafcommerce.openadmin.server.dao.Met...      4
# 3  org.broadleafcommerce.cms.admin.web.controller...     15
# 4  org.broadleafcommerce.cms.admin.web.controller...     15
# 5  org.broadleafcommerce.cms.admin.web.controller...     15
# 6  org.broadleafcommerce.cms.admin.web.controller...     15
# 7  org.broadleafcommerce.cms.admin.web.controller...     15
# 8  org.broadleafcommerce.cms.admin.web.controller...     15
# 9  org.broadleafcommerce.cms.admin.web.controller...     15
#
#                                           invocation field/param  \
# 0         dynamicEntityDao.getAllFields(targetClass)          C1
# 1  fieldMetadataProvider.addMetadata(new AddField...         !C1
# 2  defaultFieldMetadataProvider.addMetadata(new A...          C1
# 3           properties.put("entityType", sectionKey)         !C1
# 4                     properties.put("entityId", id)         !C1
# 5  staticAssetService.createStaticAssetFromFile(f...          C1
# 6  staticAssetStorageService.createStaticAssetSto...          C1
# 7       staticAssetService.getStaticAssetUrlPrefix()          C1
# 8               staticAssetUrlPrefix.startsWith("/")         !C1
# 9                           staticAsset.getFullUrl()         !C1
#
#   primitive-return  n-loc non-static  mockable category
# 0              !C2      0         C4     False   DOMAIN
# 1              !C2      0         C4     False   DOMAIN
# 2              !C2      0         C4     False   DOMAIN
# 3               C2      0         C4     False  STD_LIB
# 4               C2      0         C4     False  STD_LIB
# 5              !C2      0         C4     False   DOMAIN
# 6               C2      0         C4      True   DOMAIN
# 7               C2      0         C4      True   DOMAIN
# 8               C2      0         C4     False  STD_LIB
# 9               C2      0         C4     False   DOMAIN

# %% [markdown]
# ### Nested method categories

# %%
report['category'].value_counts()
# Out:
# DOMAIN         16276
# STD_LIB        12899
# THIRD_PARTY     7606
# Name: category, dtype: int64

# %% [markdown]
# ### Number of mockable methods

# %%
report['mockable'].value_counts()
# Out:
# False    35364
# True      1494
# Name: mockable, dtype: int64

# %% [markdown]
# ### Mockable methods

# %%
mockables = report[report['mockable'] == True]

# %%
mockables
# Out:
#                                              method-path  m-loc  \
# 6      org.broadleafcommerce.cms.admin.web.controller...     15
# 7      org.broadleafcommerce.cms.admin.web.controller...     15
# 20     org.broadleafcommerce.cms.admin.web.controller...      5
# 21     org.broadleafcommerce.cms.admin.web.controller...      5
# 72     org.broadleafcommerce.core.catalog.dao.Product...     17
# ...                                                  ...    ...
# 36809  org.broadleafcommerce.common.security.Broadlea...      2
# 36841  org.broadleafcommerce.core.catalog.domain.SkuI...      2
# 36842  org.broadleafcommerce.core.catalog.domain.SkuI...      2
# 36847  org.broadleafcommerce.core.web.order.security....      3
# 36854  org.broadleafcommerce.common.web.payment.proce...      2
#
#                                               invocation field/param  \
# 6      staticAssetStorageService.createStaticAssetSto...          C1
# 7           staticAssetService.getStaticAssetUrlPrefix()          C1
# 20     staticAssetStorageService.createStaticAssetSto...          C1
# 21          staticAssetService.getStaticAssetUrlPrefix()          C1
# 72                                 possibleSkuIds.size()          C1
# ...                                                  ...         ...
# 36809                                  url.contains(".")          C1
# 36841                   legacyProductOptionValues.size()          C1
# 36842  legacyProductOptionValues.add(xref.getProductO...          C1
# 36847            crossAppAuthService.isAuthedFromAdmin()          C1
# 36854  paymentGatewayResolver.isHandlerCompatible(get...          C1
#
#       primitive-return  n-loc non-static  mockable     category
# 6                   C2      0         C4      True       DOMAIN
# 7                   C2      0         C4      True       DOMAIN
# 20                  C2      0         C4      True       DOMAIN
# 21                  C2      0         C4      True       DOMAIN
# 72                  C2      0         C4      True      STD_LIB
# ...                ...    ...        ...       ...          ...
# 36809               C2      0         C4      True      STD_LIB
# 36841               C2      0         C4      True      STD_LIB
# 36842               C2      0         C4      True      STD_LIB
# 36847               C2      0         C4      True  THIRD_PARTY
# 36854               C2      0         C4      True       DOMAIN
#
# [1494 rows x 9 columns]

# %% [markdown]
# ### Mockable method categories

# %%
mockables['category'].value_counts()
# Out:
# STD_LIB        695
# DOMAIN         482
# THIRD_PARTY    317
# Name: category, dtype: int64

# %% [markdown]
# ## Ttorrent

# %%
report = pd.read_csv("/home/dee/dev/pankti/pankti-extract/nested-method-analysis-ttorrent.csv")

# %%
report.shape
# Out:
# (1856, 9)

# %%
report.head(10)
# Out:
#                                          method-path  m-loc  \
# 0  com.turn.ttorrent.common.Peer.setPeerId(java.n...      1
# 1  com.turn.ttorrent.common.Peer.setPeerId(java.n...      1
# 2  com.turn.ttorrent.client.Piece.record(java.nio...      5
# 3  com.turn.ttorrent.client.Piece.record(java.nio...      5
# 4  com.turn.ttorrent.client.Piece.record(java.nio...      5
# 5  com.turn.ttorrent.client.Piece.record(java.nio...      5
# 6  com.turn.ttorrent.client.Piece.record(java.nio...      5
# 7  com.turn.ttorrent.common.TorrentStatistic.addD...      1
# 8  com.turn.ttorrent.client.CommunicationManager....      1
# 9  com.turn.ttorrent.client.SharedTorrent.initIfN...      1
#
#                                           invocation field/param  \
# 0  TorrentUtils.byteArrayToHexString(peerId.array())         !C1
# 1                                     peerId.array()          C1
# 2         ByteBuffer.allocate(((int) (this.length)))         !C1
# 3                                   block.position()          C1
# 4                         this.data.position(offset)         !C1
# 5                               this.data.put(block)         !C1
# 6                                block.position(pos)          C1
# 7                 myDownloadedBytes.addAndGet(delta)          C1
# 8                             getConnectionManager()         !C1
# 9                                    isInitialized()         !C1
#
#   primitive-return  n-loc non-static  mockable category
# 0               C2      3        !C4     False   DOMAIN
# 1              !C2      0         C4     False  STD_LIB
# 2              !C2      0        !C4     False  STD_LIB
# 3               C2      0         C4      True  STD_LIB
# 4              !C2      0         C4     False  STD_LIB
# 5              !C2      0         C4     False  STD_LIB
# 6              !C2      0         C4     False  STD_LIB
# 7               C2      0         C4     False  STD_LIB
# 8              !C2      3         C4     False   DOMAIN
# 9               C2      1         C4     False   DOMAIN

# %% [markdown]
# ### Nested method categories

# %%
report['category'].value_counts()
# Out:
# DOMAIN         889
# STD_LIB        798
# THIRD_PARTY    169
# Name: category, dtype: int64

# %% [markdown]
# ### Number of mockable methods

# %%
report['mockable'].value_counts()
# Out:
# False    1702
# True      154
# Name: mockable, dtype: int64

# %% [markdown]
# ### Mockable methods

# %%
mockables = report[report['mockable'] == True]

# %%
mockables
# Out:
#                                             method-path  m-loc  \
# 3     com.turn.ttorrent.client.Piece.record(java.nio...      5
# 37    com.turn.ttorrent.network.keyProcessors.Cleanu...      3
# 39    com.turn.ttorrent.network.keyProcessors.Cleanu...      3
# 57    com.turn.ttorrent.client.SimpleClient.stop(int...      6
# 65    com.turn.ttorrent.network.ConnectionWorker.sto...      3
# ...                                                 ...    ...
# 1814  com.turn.ttorrent.network.keyProcessors.Writab...      9
# 1834  com.turn.ttorrent.network.keyProcessors.Writab...      9
# 1836  com.turn.ttorrent.tracker.MultiAnnounceRequest...      7
# 1847  com.turn.ttorrent.tracker.MultiAnnounceRequest...      7
# 1850  com.turn.ttorrent.tracker.MultiAnnounceRequest...      7
#
#                                              invocation field/param  \
# 3                                      block.position()          C1
# 37                                         key.cancel()          C1
# 39                                  myTimeService.now()          C1
# 57         communicationManager.stop(timeout, timeUnit)          C1
# 65            mySemaphore.tryAcquire(timeout, timeUnit)          C1
# ...                                                 ...         ...
# 1814                                       key.cancel()          C1
# 1834                                       key.cancel()          C1
# 1836  myTrackerRequestProcessor.process(s, hostAddre...          C1
# 1847  requestHandler.serveResponse(status.getCode(),...          C1
# 1850  requestHandler.serveResponse(isAnySuccess.get(...          C1
#
#      primitive-return  n-loc non-static  mockable category
# 3                  C2      0         C4      True  STD_LIB
# 37                 C2      0         C4      True  STD_LIB
# 39                 C2      0         C4      True   DOMAIN
# 57                 C2     12         C4      True   DOMAIN
# 65                 C2      0         C4      True  STD_LIB
# ...               ...    ...        ...       ...      ...
# 1814               C2      0         C4      True  STD_LIB
# 1834               C2      0         C4      True  STD_LIB
# 1836               C2     11         C4      True   DOMAIN
# 1847               C2      0         C4      True   DOMAIN
# 1850               C2      0         C4      True   DOMAIN
#
# [154 rows x 9 columns]

# %% [markdown]
# ### Mockable method categories

# %%
mockables['category'].value_counts()
# Out:
# STD_LIB        83
# DOMAIN         64
# THIRD_PARTY     7
# Name: category, dtype: int64
